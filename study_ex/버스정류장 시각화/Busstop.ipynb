# %%
# !pip install pandas

# %%
pip list
# Out:
# Package            Version
# ------------------ -----------
# appnope            0.1.3
# asttokens          2.2.1
# backcall           0.2.0
# branca             0.6.0
# certifi            2023.7.22
# charset-normalizer 3.2.0
# comm               0.1.4
# debugpy            1.6.7.post1
# decorator          5.1.1
# executing          1.2.0
# folium             0.14.0
# gmplot             1.4.1
# idna               3.4
# importlib-metadata 6.8.0
# ipykernel          6.25.1
# ipython            8.12.2
# jedi               0.19.0
# Jinja2             3.1.2
# jupyter_client     8.3.0
# jupyter_core       5.3.1
# MarkupSafe         2.1.3
# matplotlib-inline  0.1.6
# nest-asyncio       1.5.7
# numpy              1.24.4
# packaging          23.1
# pandas             2.0.3
# parso              0.8.3
# pexpect            4.8.0
# pickleshare        0.7.5
# pip                23.2.1
# platformdirs       3.10.0
# prompt-toolkit     3.0.39
# psutil             5.9.5
# ptyprocess         0.7.0
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
busstop = pd.read_csv('/Users/jaeyeon/Desktop/타용/세종특별자치시_버스노선 및 버스정류장20230602/세종특별자치시_노선별 정류장현황_20230602.csv', encoding ='cp949')

# %%
busstop.head(5)
# Out:
#       교통수단 노선번호                  노선명    정류장ID             정류장명  정류장수  정류장순서  \
# 0  세종시(일반)  540  540번(장군면사무소~장군면사무소)  6800133           장군면사무소     3      1
# 1  세종시(일반)  540  540번(장군면사무소~장군면사무소)  6800134          하봉리마을회관     3      2
# 2  세종시(일반)  540  540번(장군면사무소~장군면사무소)  6800124           장군면사무소     3      3
# 3  세종시(일반)  550     550번(산성동종점~조치원역)  6801913            산성동종점    62      1
# 4  세종시(일반)  550     550번(산성동종점~조치원역)  6800655  산성시장(옥룡동,공주고방면)    62      2
#
#           X좌표        Y좌표       GPS_X      GPS_Y
# 0  12712.3186  3629.8284  127.205310  36.497140
# 1  12711.4192  3629.7558  127.190320  36.495930
# 2  12712.3066  3629.8104  127.205110  36.496840
# 3  12707.4322  3627.6084  127.123870  36.460140
# 4  12707.4818  3627.5239  127.124697  36.458732

# %%
busstop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3639 entries, 0 to 3638
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   교통수단    3639 non-null   object
#  1   노선번호    3639 non-null   object
#  2   노선명     3639 non-null   object
#  3   정류장ID   3639 non-null   int64
#  4   정류장명    3639 non-null   object
#  5   정류장수    3639 non-null   int64
#  6   정류장순서   3639 non-null   int64
#  7   X좌표     3639 non-null   float64
#  8   Y좌표     3639 non-null   float64
#  9   GPS_X   3639 non-null   float64
#  10  GPS_Y   3639 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 312.9+ KB

# %%
bus = busstop.drop_duplicates(subset=['GPS_X','GPS_Y'])

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1437 entries, 0 to 3609
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   교통수단    1437 non-null   object
#  1   노선번호    1437 non-null   object
#  2   노선명     1437 non-null   object
#  3   정류장ID   1437 non-null   int64
#  4   정류장명    1437 non-null   object
#  5   정류장수    1437 non-null   int64
#  6   정류장순서   1437 non-null   int64
#  7   X좌표     1437 non-null   float64
#  8   Y좌표     1437 non-null   float64
#  9   GPS_X   1437 non-null   float64
#  10  GPS_Y   1437 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 134.7+ KB

# %%
import folium

# %%
i = 7

lat = bus.loc[i, 'GPS_X']
long = bus.loc[i, 'GPS_Y']
name = bus.loc[i,'정류장명']

print(lat, long, name)
# Out:
# 127.135852 36.456358 옥룡동 주민센터(시목동방면)

# %%
m = folium.Map(location=[36.479868, 127.289240],
               zoom_start=12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MiniMap

# 미니맵 추가하기
minimap = MiniMap()
minimap.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
bus.head(5)
# Out:
#       교통수단 노선번호                  노선명    정류장ID             정류장명  정류장수  정류장순서  \
# 0  세종시(일반)  540  540번(장군면사무소~장군면사무소)  6800133           장군면사무소     3      1
# 1  세종시(일반)  540  540번(장군면사무소~장군면사무소)  6800134          하봉리마을회관     3      2
# 2  세종시(일반)  540  540번(장군면사무소~장군면사무소)  6800124           장군면사무소     3      3
# 3  세종시(일반)  550     550번(산성동종점~조치원역)  6801913            산성동종점    62      1
# 4  세종시(일반)  550     550번(산성동종점~조치원역)  6800655  산성시장(옥룡동,공주고방면)    62      2
#
#           X좌표        Y좌표       GPS_X      GPS_Y
# 0  12712.3186  3629.8284  127.205310  36.497140
# 1  12711.4192  3629.7558  127.190320  36.495930
# 2  12712.3066  3629.8104  127.205110  36.496840
# 3  12707.4322  3627.6084  127.123870  36.460140
# 4  12707.4818  3627.5239  127.124697  36.458732

# %%
folium.Marker([36.479868, 127.289240],tooltip= name).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in range(len(bus)):
    lat = bus.loc[i, 'GPS_X']
    long = bus.loc[i, 'GPS_Y']
    name = bus.loc[i,'정류장명']

    folium.Marker([long, lat],tooltip= name).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 29
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
m.save('./bus_stops.html')
